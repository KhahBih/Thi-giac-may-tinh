# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
imagePath = "C:\\Users\\wwwkb\\OneDrive\\Desktop\\4.png"

# %%
image = Image.open(imagePath)
imageArray = np.array(image)
print(imageArray.shape)
# Out:
# (1043, 1920, 4)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

imagePath = 'C:\\Users\\wwwkb\\OneDrive\\Desktop\\4.png'
image = Image.open(imagePath)

# Chuyển đổi hình ảnh thành mảng Numpy
image_array = np.array(image.convert("L"))

# %%
invertedImage = 255 - image_array
squaredImage = image_array ** 2  # Bình phương giá trị pixel
clampedImage = np.clip(image_array, 100, 200)  # Giới hạn giá trị pixel trong khoảng 100-200

# Hiển thị hình ảnh gốc và hình ảnh đã biến đổi với khoảng trắng
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.subplots_adjust(wspace=0.2, hspace=0.2)
axs[0, 0].imshow(image_array, cmap="gray")
axs[0, 0].set_title('Hình ảnh gốc')

axs[0, 1].imshow(invertedImage, cmap="gray")
axs[0, 1].set_title('Hình ảnh đã biến đổi')

axs[1, 0].imshow(squaredImage, cmap="gray")
axs[1, 0].set_title('Hình ảnh đã biến đổi')

axs[1, 1].imshow(clampedImage, cmap="gray")
axs[1, 1].set_title('Hình ảnh đã biến đổi')
plt.show()
